# %%
import pandas as pd
from sklearn.pipeline import make_pipeline
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
import warnings;warnings.filterwarnings("ignore")
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 20

# %%
# df = pd.read_csv("Homicide_Dataset_Cleaned.csv")
# print("sample nb= ",len(df))
# print("vars nb= ",len(df.columns))
df = pd.read_csv("Edgar.csv")
print("sample nb= ",len(df))
print("vars nb= ",len(df.columns))
# Out:
# sample nb=  769753
# vars nb=  32

# %%
df.iloc[:, : 10].head()
# Out:
#                  ID       CNTYFIPS      Ori    State          Agency  \
# 0  197601001AKASP00     Juneau, AK  AKASP00   Alaska  State Troopers
# 1  197601001AL00102  Jefferson, AL  AL00102  Alabama      Birmingham
# 2  197601001AL00104  Jefferson, AL  AL00104  Alabama       Fairfield
# 3  197601001AL00106  Jefferson, AL  AL00106  Alabama           Leeds
# 4  197601001AL00201     Mobile, AL  AL00201  Alabama          Mobile
#
#            Agentype Source Solved  Year StateName
# 0  Primary state LE    FBI    Yes  1976    ALASKA
# 1  Municipal police    FBI    Yes  1976       ALA
# 2  Municipal police    FBI    Yes  1976       ALA
# 3  Municipal police    FBI    Yes  1976       ALA
# 4  Municipal police    FBI    Yes  1976       ALA

# %%
df.iloc[:,10 : 20].head()
# Out:
#      Month  Incident     ActionType                               Homicide  \
# 0  January         1  Normal update  Murder and non-negligent manslaughter
# 1  January         1  Normal update  Murder and non-negligent manslaughter
# 2  January         1  Normal update  Murder and non-negligent manslaughter
# 3  January         1  Normal update  Murder and non-negligent manslaughter
# 4  January         1     Adjustment  Murder and non-negligent manslaughter
#
#                        Situation  VicAge  VicSex  \
# 0  Single victim/single offender      48    Male
# 1  Single victim/single offender      65    Male
# 2  Single victim/single offender      45  Female
# 3  Single victim/single offender      43    Male
# 4  Single victim/single offender      35    Male
#
#                              VicRace                VicEthnic  OffAge
# 0  American Indian or Alaskan Native  Unknown or not reported      55
# 1                              Black  Unknown or not reported      67
# 2                              Black  Unknown or not reported      53
# 3                              Black  Unknown or not reported      35
# 4                              White  Unknown or not reported      25

# %%
df.iloc[:, 20 : ].head()
# Out:
#    OffSex                            OffRace                OffEthnic  \
# 0  Female  American Indian or Alaskan Native  Unknown or not reported
# 1    Male                              Black  Unknown or not reported
# 2    Male                              Black  Unknown or not reported
# 3  Female                              Black  Unknown or not reported
# 4  Female                              White  Unknown or not reported
#
#                         Weapon  Relationship                     Circumstance  \
# 0  Knife or cutting instrument       Husband                  Other arguments
# 1                      Shotgun  Acquaintance  Felon killed by private citizen
# 2                      Shotgun          Wife                            Other
# 3  Knife or cutting instrument       Brother                  Other arguments
# 4      Strangulation - hanging  Acquaintance       Circumstances undetermined
#
#                                Subcircum  VicCount  OffCount  FileDate  \
# 0                                    NaN         0         0   30180.0
# 1  Felon killed in commission of a crime         0         0   30180.0
# 2                                    NaN         0         0   30180.0
# 3                                    NaN         0         0   30180.0
# 4                                    NaN         0         0   30180.0
#
#     fstate                    MSA
# 0   Alaska           Rural Alaska
# 1  Alabama  Birmingham-Hoover, AL
# 2  Alabama  Birmingham-Hoover, AL
# 3  Alabama  Birmingham-Hoover, AL
# 4  Alabama             Mobile, AL

# %%
df.columns
# Out:
# Index(['ID', 'CNTYFIPS', 'Ori', 'State', 'Agency', 'Agentype', 'Source',
#        'Solved', 'Year', 'StateName', 'Month', 'Incident', 'ActionType',
#        'Homicide', 'Situation', 'VicAge', 'VicSex', 'VicRace', 'VicEthnic',
#        'OffAge', 'OffSex', 'OffRace', 'OffEthnic', 'Weapon', 'Relationship',
#        'Circumstance', 'Subcircum', 'VicCount', 'OffCount', 'FileDate',
#        'fstate', 'MSA'],
#       dtype='object')

# %%
df.dtypes
# Out:
# ID               object
# CNTYFIPS         object
# Ori              object
# State            object
# Agency           object
# Agentype         object
# Source           object
# Solved           object
# Year              int64
# StateName        object
# Month            object
# Incident          int64
# ActionType       object
# Homicide         object
# Situation        object
# VicAge            int64
# VicSex           object
# VicRace          object
# VicEthnic        object
# OffAge            int64
# OffSex           object
# OffRace          object
# OffEthnic        object
# Weapon           object
# Relationship     object
# Circumstance     object
# Subcircum        object
# VicCount          int64
# OffCount          int64
# FileDate        float64
# fstate           object
# MSA              object
# dtype: object

# %%
df['Incident'].value_counts()
# Out:
# 1      315786
# 2       86621
# 3       47063
# 4       32446
# 5       24605
#         ...
# 774        27
# 773        27
# 772        27
# 770        27
# 0          27
# Name: Incident, Length: 1000, dtype: int64

# %%
df['MSA'].value_counts()
# Out:
# New York-New Jersey-Long Island, NY-NJ    61292
# Los Angeles-Long Beach, CA                55770
# Chicago-Naperville-Joliet, IL-IN-WI       33615
# Detroit-Warren-Livonia, MI                24853
# Houston-Sugar Land-Baytown, TX            22922
#                                           ...
# Logan, UT-ID                                 38
# Dubuque, IA                                  38
# Carson City, NV                              36
# Ames, IA                                     27
# Rural Massachusetts                           8
# Name: MSA, Length: 409, dtype: int64

# %%
df['Circumstance'].value_counts()
# Out:
# Other arguments                         201602
# Circumstances undetermined              200717
# Other                                    99600
# Robbery                                  59716
# Narcotic drug laws                       28823
# Other - not specified                    25566
# Juvenile gang killings                   24040
# Felon killed by police                   16528
# Brawl due to influence of alcohol        16143
# Argument over money or property          15371
# All suspected felony type                13265
# Felon killed by private citizen          12699
# Lovers triangle                          12064
# Burglary                                  6400
# Brawl due to influence of narcotics       5149
# Gangland killings                         4845
# All other manslaughter by negligence      4764
# Arson                                     4581
# Rape                                      4191
# Other negligent handling of gun           3642
# Other sex offense                         1449
# Children playing with gun                 1391
# Motor vehicle theft                       1286
# Child killed by babysitter                1276
# Institutional killings                    1080
# Gambling                                  1075
# Larceny                                    758
# Prostitution and commercialized vice       614
# Sniper attack                              551
# Victim shot in hunting accident            411
# Gun-cleaning death - other than self       146
# Abortion                                    10
# Name: Circumstance, dtype: int64

# %%
to_print= [ 'Agentype', 'Source',
       'Solved', 'Year', 'Month',
       'Homicide', 'Situation', 'VicAge', 'VicSex', 'VicRace', 'VicEthnic',
       'OffAge', 'OffSex', 'OffRace', 'OffEthnic', 'Weapon', 'Relationship',
       'Circumstance', 'Subcircum', 'VicCount', 'OffCount', 
       'State']

# %%
aug_df = pd.DataFrame()
for var in df.columns:
    if df[var].dtypes == 'int64':
        aug_df[var] = df[var]
    elif len(df[var].value_counts()) <= 30 and var in to_print:
        dummies = pd.get_dummies(df[var],prefix=var)
        aug_df = pd.concat([aug_df, dummies], axis=1)
        fig = plt.figure(figsize=(8,8))
        ax = fig.add_subplot(1, 1, 1)
        df[var].value_counts().sort_index().plot.bar()
        plt.title(var)

# %%
all_corrs = aug_df.corr()

all_corrs_list = []
i = 0;
for col in all_corrs.columns:
    i+=1;
    for row in all_corrs.index[i:]:
        a ="Unknown" not in col
        b ="Unknown" not in row
        if a and b: 
            all_corrs_list.append((col, row, abs(all_corrs[col][row])))
        
sorted_list = list(sorted(all_corrs_list,key = lambda i: i[2]))

# %%
print("See if there are any redundant variables")
for i in range(6,30):
    print(sorted_list[len(sorted_list)-i])
# Out:
# See if there are any redundant variables
# ('Solved_Yes', 'Situation_Single victim/unknown offender(s)', 0.9348210714909271)
# ('Solved_No', 'Situation_Single victim/unknown offender(s)', 0.9348210714909271)
# ('Solved_Yes', 'OffAge', 0.9071367740832512)
# ('Solved_No', 'OffAge', 0.9071367740832512)
# ('Situation_Single victim/unknown offender(s)', 'OffAge', 0.8535524397917996)
# ('Agentype_Municipal police', 'Agentype_Sheriff', 0.8405849163802621)
# ('Solved_Yes', 'OffSex_Male', 0.8338854753627057)
# ('Solved_No', 'OffSex_Male', 0.8338854753627057)
# ('Source_MAP', 'Incident', 0.8264859611475474)
# ('Source_FBI', 'Incident', 0.8264859611475474)
# ('Situation_Single victim/unknown offender(s)', 'OffSex_Male', 0.779369376416816)
# ('Situation_Single victim/multiple offenders', 'OffCount', 0.7588780969850621)
# ('OffAge', 'OffSex_Male', 0.7469921651814598)
# ('Solved_Yes', 'Relationship_Relationship not determined', 0.7244981696921782)
# ('Solved_No', 'Relationship_Relationship not determined', 0.7244981696921782)
# ('VicEthnic_Not of Hispanic origin', 'OffEthnic_Not of Hispanic origin', 0.7244664316994136)
# ('OffAge', 'Relationship_Relationship not determined', 0.7167281792486396)
# ('Solved_Yes', 'Situation_Single victim/single offender', 0.6999537659300633)
# ('Solved_No', 'Situation_Single victim/single offender', 0.6999537659300633)
# ('Situation_Single victim/unknown offender(s)', 'Relationship_Relationship not determined', 0.6782510073259758)
# ('Situation_Single victim/single offender', 'Situation_Single victim/unknown offender(s)', 0.6670202484329243)
# ('Situation_Single victim/single offender', 'OffAge', 0.6527330469186512)
# ('VicEthnic_Hispanic origin', 'OffEthnic_Hispanic origin', 0.5943104217213097)
# ('VicRace_White', 'OffRace_White', 0.5866044122454289)

# %%
print("Discrete variables :")
print(df.dtypes[df.dtypes == "object"])
print("missing values: ")
print(df[:].isnull().sum().sort_values(ascending = False))
# Out:
# Discrete variables :
# ID              object
# CNTYFIPS        object
# Ori             object
# State           object
# Agency          object
# Agentype        object
# Source          object
# Solved          object
# StateName       object
# Month           object
# ActionType      object
# Homicide        object
# Situation       object
# VicSex          object
# VicRace         object
# VicEthnic       object
# OffSex          object
# OffRace         object
# OffEthnic       object
# Weapon          object
# Relationship    object
# Circumstance    object
# Subcircum       object
# fstate          object
# MSA             object
# dtype: object
# missing values:
# Subcircum       740569
# FileDate          1232
# MSA                  0
# Solved               0
# ActionType           0
# Incident             0
# Month                0
# StateName            0
# Year                 0
# Agentype             0
# Source               0
# Situation            0
# Agency               0
# State                0
# Ori                  0
# CNTYFIPS             0
# Homicide             0
# VicAge               0
# fstate               0
# VicSex               0
# VicRace              0
# VicEthnic            0
# OffAge               0
# OffSex               0
# OffRace              0
# OffEthnic            0
# Weapon               0
# Relationship         0
# Circumstance         0
# VicCount             0
# OffCount             0
# ID                   0
# dtype: int64

# %%
print((df[:]=="Unknown").sum().sort_values(ascending =False))
# Out:
# OffRace         233623
# OffSex          226600
# VicRace           8332
# VicSex            1242
# Agency              42
# MSA                  0
# Incident             0
# Month                0
# StateName            0
# Year                 0
# Homicide             0
# Solved               0
# Source               0
# Agentype             0
# State                0
# Ori                  0
# CNTYFIPS             0
# ActionType           0
# VicAge               0
# Situation            0
# fstate               0
# VicEthnic            0
# OffAge               0
# OffEthnic            0
# Weapon               0
# Relationship         0
# Circumstance         0
# Subcircum            0
# VicCount             0
# OffCount             0
# FileDate             0
# ID                   0
# dtype: int64

# %%
sums =[]
missing_vars = []
for v in df.columns:
    this_sum = int(df[v].isnull().sum())
    try:
        unk=sum(df[v].str.contains("nknown|undetermined|not specified",regex = True))
        if not np.isnan(unk):
            this_sum+=unk
    except: 
        a=0
    sums.append(this_sum)
    
missing_vars = pd.Series(index = df.columns, data =sums)
# Out:
# Text(0.5, 1.0, 'missing values per variables')

# %%
fig = plt.figure(figsize=(8,8))
missing_vars[missing_vars>0].sort_values(ascending = False).plot.bar(label = "total missing samples")
plt.axhline(y=len(df),linewidth=3, color='r', linestyle='-', label = "total number of samples")
plt.title("Missing value counts per variables")
plt.legend()
plt.rcParams['font.size'] = 30

# %%
df_sub = df.drop(["Subcircum","OffEthnic","VicEthnic"],axis = 1)

print(len(df_sub))
df_sub_full = df_sub.dropna()
print(len(df_sub_full))

for col in df_sub.columns:
    try:
        df_sub_full = df_sub_full[df_sub_full[col].str.contains("nknown|undetermined|not specified",regex = True)==False]
    except:
            a=0
print(len(df_sub_full))
# Out:
# 769753
# 768521
# 425886

# %%
df_sub_full.to_csv('non_empty_sample.csv')

# %%
df_miss = df_sub.drop(df_sub_full.index)

# %%
len(df_miss)
# Out:
# 343867

# %%
df_miss.to_csv('missing_sample.csv')

# %%
for i in df.columns:
    x=df[i].value_counts()
    print(x)
# Out:
# 197702001NY05904    13
# 199204001FL05003    12
# 201405001CA04200    12
# 201207003CO00101    10
# 198302005WASPD00    10
#                     ..
# 200504002TNMPD00     1
# 200902017TXHPD00     1
# 199602001IN07102     1
# 199411001VA10900     1
# 200704001NJ00408     1
# Name: ID, Length: 735419, dtype: int64
# Los Angeles, CA              51417
# New York, NY                 45376
# Cook, IL                     28263
# Wayne, MI                    22577
# Harris, TX                   19844
#                              ...
# Winnebago, IA                    1
# Henderson, IL                    1
# Bon Homme, SD                    1
# Skagway-Hoonah-Angoon, AK        1
# Ida, IA                          1
# Name: CNTYFIPS, Length: 3061, dtype: int64
# NY03030    45359
# CA01942    27166
# ILCPD00    26782
# MI82349    20359
# TXHPD00    15784
#            ...
# MN05900        1
# MI82624        1
# OH07709        1
# TX08904        1
# TX03711        1
# Name: Ori, Length: 12729, dtype: int64
# California              116613
# Texas                    74041
# New York                 58384
# Florida                  44691
# Michigan                 34027
# Illinois                 33571
# Pennsylvania             29406
# Georgia                  25324
# North Carolina           24536
# Ohio                     24064
# Louisiana                23814
# Maryland                 20269
# Virginia                 18803
# Missouri                 18429
# Tennessee                18013
# New Jersey               16959
# Alabama                  15689
# Arizona                  14942
# South Carolina           14385
# Indiana                  13867
# Oklahoma                 10609
# Washington                9130
# Kentucky                  8756
# Arkansas                  8348
# District of Columbia      8334
# Colorado                  7947
# Mississippi               7844
# Wisconsin                 7521
# Massachusetts             7234
# Nevada                    6664
# Connecticut               5644
# New Mexico                5048
# Oregon                    4960
# Minnesota                 4766
# Kansas                    3949
# West Virginia             3769
# Utah                      2431
# Iowa                      2254
# Alaska                    2027
# Hawaii                    1700
# Nebraska                  1678
# Delaware                  1508
# Idaho                     1458
# Rhodes Island             1417
# Maine                     1077
# Montana                    843
# Wyoming                    791
# New Hampshire              782
# South Dakota               561
# Vermont                    483
# North Dakota               393
# Name: State, dtype: int64
# New York           45359
# Los Angeles        27166
# Chicago            26782
# Detroit            20359
# Houston            15784
#                    ...
# Yakama Nation          1
# Bogata                 1
# Cuyahoga County        1
# North Newton           1
# Idalou                 1
# Name: Agency, Length: 9442, dtype: int64
# Municipal police    597541
# Sheriff             130231
# County police        21808
# Primary state LE     18211
# Special police        1404
# Regional police        324
# Tribal                 234
# Name: Agentype, dtype: int64
# FBI    741509
# MAP     28244
# Name: Source, dtype: int64
# Yes    543510
# No     226243
# Name: Solved, dtype: int64
# 1993    24336
# 1992    23793
# 1994    23246
# 1980    23092
# 1991    22657
# 1979    21698
# 1990    21246
# 1981    21208
# 1995    21179
# 1982    20544
# 1986    20125
# 1989    19868
# 1983    19653
# 1978    19523
# 1996    18996
# 1977    18844
# 1987    18783
# 1988    18779
# 1985    18386
# 1984    18093
# 2016    18022
# 1997    17830
# 1976    17619
# 2017    17440
# 2007    17327
# 2006    17294
# 2005    16852
# 2003    16532
# 2015    16357
# 2002    16287
# 2004    16246
# 1998    16089
# 2009    15857
# 2001    15821
# 2008    15610
# 2012    15390
# 2010    15133
# 2011    15119
# 2013    14841
# 2014    14702
# 2000    14692
# 1999    14644
# Name: Year, dtype: int64
# CALIF     116613
# TEXAS      74041
# N Y        58384
# FLA        44691
# MICH       34027
# ILL        33571
# PA         29406
# GA         25324
# N C        24536
# OHIO       24064
# LA         23814
# MD         20269
# VA         18803
# MO         18429
# TENN       18013
# N J        16959
# ALA        15689
# ARIZ       14942
# S C        14385
# IND        13867
# OKLA       10609
# WASH        9130
# KY          8756
# ARK         8348
# D C         8334
# COLO        7947
# MISS        7844
# WIS         7521
# MASS        7234
# NEV         6664
# CONN        5634
# N MEX       5048
# OREG        4960
# MINN        4766
# KANS        3949
# W VA        3769
# UTAH        2431
# IOWA        2254
# ALASKA      2027
# HAWAII      1700
# NEBR        1678
# DEL         1508
# IDAHO       1458
# R I         1417
# MAINE       1077
# MONT         843
# WYO          791
# N H          782
# S DAK        561
# VT           483
# N DAK        393
# CONN.         10
# Name: StateName, dtype: int64
# July         70442
# August       69575
# December     66810
# September    65322
# October      64881
# June         64432
# May          64429
# January      63658
# March        61964
# April        61509
# November     60980
# February     55751
# Name: Month, dtype: int64
# 1      315786
# 2       86621
# 3       47063
# 4       32446
# 5       24605
#         ...
# 774        27
# 773        27
# 772        27
# 770        27
# 0          27
# Name: Incident, Length: 1000, dtype: int64
# Normal update    603195
# Adjustment       157144
# 9                  2425
# 2                  2067
# 3                  1345
# 4                  1046
# 8                   909
# 5                   862
# 6                   558
# 7                   202
# Name: ActionType, dtype: int64
# Murder and non-negligent manslaughter    758861
# Manslaughter by negligence                10892
# Name: Homicide, dtype: int64
# Single victim/single offender           422472
# Single victim/unknown offender(s)       206133
# Single victim/multiple offenders         77587
# Multiple victims/single offender         35482
# Multiple victims/unknown offender(s)     17382
# Multiple victims/multiple offenders      10697
# Name: Situation, dtype: int64
# 22    27614
# 25    27521
# 21    27162
# 20    27059
# 23    26937
#       ...
# 99      133
# 95      110
# 96       48
# 97       47
# 98       35
# Name: VicAge, Length: 101, dtype: int64
# Male       595859
# Female     172652
# Unknown      1242
# Name: VicSex, dtype: int64
# White                                382109
# Black                                362568
# Asian or Pacific Islander             11071
# Unknown                                8332
# American Indian or Alaskan Native      5673
# Name: VicRace, dtype: int64
# Unknown or not reported    473766
# Not of Hispanic origin     217069
# Hispanic origin             78918
# Name: VicEthnic, dtype: int64
# 999    255890
# 20      25446
# 19      23810
# 21      22736
# 22      22384
#         ...
# 3           8
# 5           5
# 1           4
# 97          4
# 2           3
# Name: OffAge, Length: 101, dtype: int64
# Male       481922
# Unknown    226600
# Female      61231
# Name: OffSex, dtype: int64
# White                                263681
# Black                                261223
# Unknown                              233623
# Asian or Pacific Islander              6768
# American Indian or Alaskan Native      4458
# Name: OffRace, dtype: int64
# Unknown or not reported    561933
# Not of Hispanic origin     157337
# Hispanic origin             50483
# Name: OffEthnic, dtype: int64
# Handgun - pistol, revolver, etc         378477
# Knife or cutting instrument             114519
# Firearm, type not stated                 60959
# Personal weapons, includes beating       44654
# Other or type unknown                    38745
# Shotgun                                  38496
# Blunt object - hammer, club, etc         34705
# Rifle                                    29150
# Strangulation - hanging                   9891
# Fire                                      7576
# Asphyxiation - includes death by gas      4712
# Other gun                                 2879
# Narcotics or drugs, sleeping pills        2124
# Drowning                                  1474
# Explosives                                 603
# Poison - does not include gas              538
# Pushed or thrown out window                251
# Name: Weapon, dtype: int64
# Relationship not determined    291986
# Acquaintance                   152631
# Stranger                       114742
# Other - known to victim         34550
# Wife                            28444
# Friend                          26698
# Girlfriend                      19410
# Son                             11935
# Husband                         11910
# Other family                    11483
# Boyfriend                        8901
# Daughter                         8884
# Neighbor                         8023
# Brother                          6753
# Father                           5546
# Mother                           5233
# In-law                           4778
# Common-law wife                  3252
# Common-law husband               2695
# Ex-wife                          2376
# Stepfather                       1738
# Homosexual relationship          1663
# Sister                           1601
# Stepson                          1468
# Ex-husband                        876
# Stepdaughter                      871
# Employer                          578
# Employee                          461
# Stepmother                        267
# Name: Relationship, dtype: int64
# Other arguments                         201602
# Circumstances undetermined              200717
# Other                                    99600
# Robbery                                  59716
# Narcotic drug laws                       28823
# Other - not specified                    25566
# Juvenile gang killings                   24040
# Felon killed by police                   16528
# Brawl due to influence of alcohol        16143
# Argument over money or property          15371
# All suspected felony type                13265
# Felon killed by private citizen          12699
# Lovers triangle                          12064
# Burglary                                  6400
# Brawl due to influence of narcotics       5149
# Gangland killings                         4845
# All other manslaughter by negligence      4764
# Arson                                     4581
# Rape                                      4191
# Other negligent handling of gun           3642
# Other sex offense                         1449
# Children playing with gun                 1391
# Motor vehicle theft                       1286
# Child killed by babysitter                1276
# Institutional killings                    1080
# Gambling                                  1075
# Larceny                                    758
# Prostitution and commercialized vice       614
# Sniper attack                              551
# Victim shot in hunting accident            411
# Gun-cleaning death - other than self       146
# Abortion                                    10
# Name: Circumstance, dtype: int64
# Felon killed in commission of a crime    10501
# Felon attacked police officer             8607
# Felon attacked a civilian                 4632
# Not enough information to determine       2402
# Felon resisted arrest                     1237
# Felon attacked fellow police officer       957
# Felon attempted flight from a crime        848
# Name: Subcircum, dtype: int64
# 0     706095
# 1      46654
# 2      10031
# 3       3608
# 4       1346
# 5        620
# 9        410
# 6        365
# 10       225
# 7        208
# 8        191
# Name: VicCount, dtype: int64
# 0     676668
# 1      63609
# 2      18564
# 3       7778
# 4       1787
# 5        736
# 6        262
# 7        160
# 8         72
# 9         62
# 10        55
# Name: OffCount, dtype: int64
# 30180.0     77684
# 61218.0     16208
# 30101.0      6375
# 11818.0      4714
# 11017.0      4412
#             ...
# 103117.0        1
# 21102.0         1
# 21015.0         1
# 62581.0         1
# 102391.0        1
# Name: FileDate, Length: 5347, dtype: int64
# California              116613
# Texas                    74041
# New York                 58384
# Florida                  44690
# Michigan                 34027
# Illinois                 33571
# Pennsylvania             29406
# Georgia                  25324
# North Carolina           24536
# Ohio                     24064
# Louisiana                23814
# Maryland                 20269
# Virginia                 18803
# Missouri                 18429
# Tennessee                18013
# New Jersey               16959
# Alabama                  15689
# Arizona                  14942
# South Carolina           14385
# Indiana                  13867
# Oklahoma                 10609
# Washington                9130
# Kentucky                  8756
# Arkansas                  8348
# District of Columbia      8334
# Colorado                  7947
# Mississippi               7844
# Wisconsin                 7521
# Massachusetts             7234
# Nevada                    6664
# Connecticut               5644
# New Mexico                5048
# Oregon                    4960
# Minnesota                 4766
# Kansas                    3949
# West Virginia             3769
# Utah                      2431
# Iowa                      2254
# Alaska                    2027
# Hawaii                    1700
# Nebraska                  1678
# Delaware                  1508
# Idaho                     1458
# Rhode Island              1417
# Maine                     1077
# Montana                    843
# Wyoming                    791
# New Hampshire              782
# South Dakota               561
# Vermont                    483
# North Dakota               393
# Florid                       1
# Name: fstate, dtype: int64
# New York-New Jersey-Long Island, NY-NJ    61292
# Los Angeles-Long Beach, CA                55770
# Chicago-Naperville-Joliet, IL-IN-WI       33615
# Detroit-Warren-Livonia, MI                24853
# Houston-Sugar Land-Baytown, TX            22922
#                                           ...
# Dubuque, IA                                  38
# Logan, UT-ID                                 38
# Carson City, NV                              36
# Ames, IA                                     27
# Rural Massachusetts                           8
# Name: MSA, Length: 409, dtype: int64
